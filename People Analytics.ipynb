# %% [markdown]
# # Análise de Recursos Humanos

# %% [markdown]
# # Colunas
#
# - ID RH
# - Nome Completo
# - Sexo
# - Data de Nascimento
# - Idade
# - Endereço
# - Data de Contratação
# - Data de Dmeissão
# - Salário Base
# - Impostos
# - Benefícios
# - VT
# - VR
# - Salário Total
# - Cargo
# - Nível
# - Área
# - Tempo de Empresa
# - Faixa de Tempo
# - Férias Acumuladas
# - Horas Extras
# - Avaliação do Funcionário
# - Trabalho em Equipe
# - Liderança
# - Comunicação
# - Iniciativa
# - Organização

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
tabela_RH = pd.read_excel("RH.xlsx")
pd.set_option('display.max_columns', None) 
display(tabela_RH)
# Out:
#     ID RH                 Nome Completo       Sexo Data de Nascimento  Idade  \
# 0       1             Bárbara Rodrigues   Feminino         1999-03-14     24
# 1       2      Bárbara Spenchutt Vieira   Feminino         1997-09-30     26
# 2       3              Camila Regis Ivo   Feminino         1992-07-01     31
# 3       4              Gabriela e Alves   Feminino         1999-05-09     24
# 4       5  Guilherme Lopes da Silveira   Masculino         1999-11-30     23
# 5       6                Jeferson Ramos  Masculino         1995-05-07     28
# 6       7       Jéssica de Morais Silva   Feminino         1979-09-16     44
# 7       8                 João Monteiro  Masculino         1988-04-26     35
# 8       9                João Resinente  Masculino         1996-09-15     27
# 9      10           José do Vale Lisboa  Masculino         1989-11-18     33
# 10     11      Juan Fernandes de Araújo  Masculino         1978-01-19     45
# ...

# %%
tabela_RH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID RH                     31 non-null     int64
#  1   Nome Completo             31 non-null     object
#  2   Sexo                      31 non-null     object
#  3   Data de Nascimento        31 non-null     datetime64[ns]
#  4   Idade                     31 non-null     int64
#  5   Endereço                  31 non-null     object
#  6   Data de Contratacao       31 non-null     datetime64[ns]
#  7   Data de Demissao          6 non-null      datetime64[ns]
#  8   Salario Base              31 non-null     int64
#  9   Impostos                  31 non-null     float64
#  10  Beneficios                31 non-null     float64
#  11  VT                        31 non-null     float64
#  12  VR                        31 non-null     float64
# ...

# %%
tabela_RH.describe()
# Out:
#            ID RH      Idade  Salario Base     Impostos   Beneficios  \
# count  31.000000  31.000000     31.000000    31.000000    31.000000
# mean   16.000000  31.612903   6516.064516   389.669355   544.173548
# std     9.092121   7.177174   4718.651000   326.666458   479.362102
# min     1.000000  23.000000    872.000000    28.770000    47.950000
# 25%     8.500000  26.000000   1697.000000   113.655000   165.135000
# 50%    16.000000  28.000000   6286.000000   313.100000   304.500000
# 75%    23.500000  37.000000  10732.500000   608.650000   858.270000
# max    31.000000  45.000000  16466.000000  1072.880000  1607.980000
#
#                 VT           VR  Salário Total  TEMPO DE EMPRESA  \
# count    31.000000    31.000000      31.000000         31.000000
# mean    551.729032   662.074839    8663.711290          8.161290
# std     411.225641   493.470769    6336.423512          1.733912
# min      87.200000   104.640000    1229.520000          4.000000
# ...

# %%
tabela_RH.shape
# Out:
# (31, 27)

# %%
tabela_RH.dtypes
# Out:
# ID RH                                int64
# Nome Completo                       object
# Sexo                                object
# Data de Nascimento          datetime64[ns]
# Idade                                int64
# Endereço                            object
# Data de Contratacao         datetime64[ns]
# Data de Demissao            datetime64[ns]
# Salario Base                         int64
# Impostos                           float64
# Beneficios                         float64
# VT                                 float64
# VR                                 float64
# Salário Total                      float64
# Cargo                               object
# Nível                               object
# Área                                object
# TEMPO DE EMPRESA                     int64
# FAIXA DE TEMPO                      object
# Ferias Acumuladas                    int64
# Horas Extras                         int64
# Avaliação do Funcionário           float64
# ...

# %%
tabela_RH.isnull().sum()
# Out:
# ID RH                        0
# Nome Completo                0
# Sexo                         0
# Data de Nascimento           0
# Idade                        0
# Endereço                     0
# Data de Contratacao          0
# Data de Demissao            25
# Salario Base                 0
# Impostos                     0
# Beneficios                   0
# VT                           0
# VR                           0
# Salário Total                0
# Cargo                        0
# Nível                        0
# Área                         0
# TEMPO DE EMPRESA             0
# FAIXA DE TEMPO               0
# Ferias Acumuladas            0
# Horas Extras                 0
# Avaliação do Funcionário     0
# Trabalho em Equipe           0
# Liderança                    0
# Comunicação                  0
# Iniciativa                   0
# Organização                  0
# dtype: int64

# %%
sns.heatmap(tabela_RH.corr())
# Out:
# C:\Users\Francianne\AppData\Local\Temp\ipykernel_127628\3630274927.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(tabela_RH.corr())
# <Axes: >

# %%
# Avaliando os salários

sns.barplot(tabela_RH, x="Salario Base", y="Nome Completo")
# Out:
# <Axes: xlabel='Salario Base', ylabel='Nome Completo'>

# %%
# Avaliando férias

sns.barplot(tabela_RH, x="Ferias Acumuladas", y="Nome Completo", color="seagreen")
# Out:
# <Axes: xlabel='Ferias Acumuladas', ylabel='Nome Completo'>

# %%
# Avaliando hora extra 

sns.barplot(tabela_RH, x="Horas Extras", y="Nome Completo", color="#69d")
# Out:
# <Axes: xlabel='Horas Extras', ylabel='Nome Completo'>

# %%
# Ranking dos colaboradores

sns.barplot(tabela_RH, x= "Avaliação do Funcionário", y= "Nome Completo", color="Yellow")
# Out:
# <Axes: xlabel='Avaliação do Funcionário', ylabel='Nome Completo'>

# %%
sns.countplot(tabela_RH, x="Avaliação do Funcionário", color="c")
# Out:
# <Axes: xlabel='Avaliação do Funcionário', ylabel='count'>

# %%
# Orçamento total dos salários, benefícios e afins: R$ 268.575,05


tabela_RH["Salário Total"].sum()
# Out:
# 268575.05

# %%
# Benefícios por cargo 

sns.boxplot(tabela_RH, x="Beneficios", y="Nível")
# Out:
# <Axes: xlabel='Beneficios', ylabel='Nível'>
